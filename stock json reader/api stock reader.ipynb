# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json
import pprint
import csv
# API Key
from config import api_key

# %%
base_url = "https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol="
stocks_dict_list = {"Basic Industries" : ["PG", "UL", "UN", "BHP", "RIO"], 
               "Finance" : ["JPM", "BAC", "WFC", "HSBC", "C"],
               "Energy" : ["XOM", "CVX", "BP", "TOT", "BBL"],
               "Consumer Durables" : ["ABB", "KMB", "AME", "BLL", "CLX"],
               "Consumer Non-Durables" : ["KO", "PEP", "FMX", "BUD", "NKE"],
                "Transports" : ["DAL", "CSX", "CHRW", "UPS", "UAL"],
                "Healthcare" : ["CVS", "UNH", "AET", "PFE", "THC"],
                "Communications" : ["S", "T", "VZ", "CMCSA", "TMUS"],
                "Real Estate" : ["LEN", "AMT", "SPG", "NLY", "PLD"],
                 "Big 5" : ["AAPL", "FB", "GOOGL", "AMZN", "MSFT"]}

keys = list(stocks_dict_list.keys())
values = list(stocks_dict_list.values())
print(values)
# Out:
# [['PG', 'UL', 'UN', 'BHP', 'RIO'], ['JPM', 'BAC', 'WFC', 'HSBC', 'C'], ['XOM', 'CVX', 'BP', 'TOT', 'BBL'], ['ABB', 'KMB', 'AME', 'BLL', 'CLX'], ['KO', 'PEP', 'FMX', 'BUD', 'NKE'], ['DAL', 'CSX', 'CHRW', 'UPS', 'UAL'], ['CVS', 'UNH', 'AET', 'PFE', 'THC'], ['S', 'T', 'VZ', 'CMCSA', 'TMUS'], ['LEN', 'AMT', 'SPG', 'NLY', 'PLD'], ['AAPL', 'FB', 'GOOGL', 'AMZN', 'MSFT']]

# %%
combined_stocks = values[0] + values[1] + values[2] + values[3] + values[4] + values[5] + values[6] + values[7] + values[8] + values[9] 
volumes = []
closes = []
len(values)
# Out:
# 10

# %%
for key in keys:
    five_stocks = stocks_dict_list[key]
    for stock in five_stocks:
        target_url = f"{base_url}{stock}&outputsize=full&apikey={api_key}"
        response = requests.get(target_url).json()
        try:
            rsp = response['Time Series (Daily)']
            dates = list(response['Time Series (Daily)'].keys())
        except KeyError:
            print("Error")
        for date in dates:
            closes.append(rsp[date]['4. close'])
            volumes.append(rsp[date]['5. volume'])
# Out:
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error

# %%
# The volumes and closes columns are 25 times larger than the dates;
# this function splits these two columns into n equal sized chunks, same 
# length as the dates

# %%
def chunks(l, n):
    """Yield successive n-sized chunks from l."""
    for i in range(0, len(l), n):
        yield l[i:i + n]
        
vols = list(chunks(volumes, len(dates)))

clos = list(chunks(closes, len(dates)))
stock_dicts["AAPL"]
# Out:
# {'Date': ['2019-05-07',
#   '2019-05-06',
#   '2019-05-03',
#   '2019-05-02',
#   '2019-05-01',
#   '2019-04-30',
#   '2019-04-29',
#   '2019-04-26',
#   '2019-04-25',
#   '2019-04-24',
#   '2019-04-23',
#   '2019-04-22',
#   '2019-04-18',
#   '2019-04-17',
#   '2019-04-16',
#   '2019-04-15',
#   '2019-04-12',
#   '2019-04-11',
#   '2019-04-10',
#   '2019-04-09',
#   '2019-04-08',
#   '2019-04-05',
#   '2019-04-04',
#   '2019-04-03',
#   '2019-04-02',
#   '2019-04-01',
#   '2019-03-29',
#   '2019-03-28',
#   '2019-03-27',
#   '2019-03-26',
#   '2019-03-25',
#   '2019-03-22',
#   '2019-03-21',
#   '2019-03-20',
#   '2019-03-19',
#   '2019-03-18',
#   '2019-03-15',
#   '2019-03-14',
#   '2019-03-13',
#   '2019-03-12',
#   '2019-03-11',
#   '2019-03-08',
#   '2019-03-07',
#   '2019-03-06',
#   '2019-03-05',
#   '2019-03-04',
#   '2019-03-01',
#   '2019-02-28',
#   '2019-02-27',
#   '2019-02-26',
#   '2019-02-25',
#   '2019-02-22',
#   '2019-02-21',
#   '2019-02-20',
#   '2019-02-19',
#   '2019-02-15',
#   '2019-02-14',
#   '2019-02-13',
#   '2019-02-12',
#   '2019-02-11',
#   '2019-02-08',
#   '2019-02-07',
#   '2019-02-06',
#   '2019-02-05',
#   '2019-02-04',
#   '2019-02-01',
#   '2019-01-31',
#   '2019-01-30',
#   '2019-01-29',
#   '2019-01-28',
#   '2019-01-25',
#   '2019-01-24',
#   '2019-01-23',
#   '2019-01-22',
#   '2019-01-18',
#   '2019-01-17',
#   '2019-01-16',
#   '2019-01-15',
#   '2019-01-14',
#   '2019-01-11',
#   '2019-01-10',
#   '2019-01-09',
#   '2019-01-08',
#   '2019-01-07',
#   '2019-01-04',
#   '2019-01-03',
#   '2019-01-02',
#   '2018-12-31',
#   '2018-12-28',
#   '2018-12-27',
#   '2018-12-26',
#   '2018-12-24',
#   '2018-12-21',
#   '2018-12-20',
#   '2018-12-19',
#   '2018-12-18',
#   '2018-12-17',
#   '2018-12-14',
#   '2018-12-13',
#   '2018-12-12',
#   '2018-12-11',
#   '2018-12-10',
#   '2018-12-07',
#   '2018-12-06',
#   '2018-12-04',
#   '2018-12-03',
#   '2018-11-30',
#   '2018-11-29',
#   '2018-11-28',
#   '2018-11-27',
#   '2018-11-26',
#   '2018-11-23',
#   '2018-11-21',
#   '2018-11-20',
#   '2018-11-19',
#   '2018-11-16',
#   '2018-11-15',
#   '2018-11-14',
#   '2018-11-13',
#   '2018-11-12',
#   '2018-11-09',
#   '2018-11-08',
#   '2018-11-07',
#   '2018-11-06',
#   '2018-11-05',
#   '2018-11-02',
#   '2018-11-01',
#   '2018-10-31',
#   '2018-10-30',
#   '2018-10-29',
#   '2018-10-26',
#   '2018-10-25',
#   '2018-10-24',
#   '2018-10-23',
#   '2018-10-22',
#   '2018-10-19',
#   '2018-10-18',
#   '2018-10-17',
#   '2018-10-16',
#   '2018-10-15',
#   '2018-10-12',
#   '2018-10-11',
#   '2018-10-10',
#   '2018-10-09',
#   '2018-10-08',
#   '2018-10-05',
#   '2018-10-04',
#   '2018-10-03',
#   '2018-10-02',
#   '2018-10-01',
#   '2018-09-28',
#   '2018-09-27',
#   '2018-09-26',
#   '2018-09-25',
#   '2018-09-24',
#   '2018-09-21',
#   '2018-09-20',
#   '2018-09-19',
#   '2018-09-18',
#   '2018-09-17',
#   '2018-09-14',
#   '2018-09-13',
#   '2018-09-12',
#   '2018-09-11',
#   '2018-09-10',
#   '2018-09-07',
#   '2018-09-06',
#   '2018-09-05',
#   '2018-09-04',
#   '2018-08-31',
#   '2018-08-30',
#   '2018-08-29',
#   '2018-08-28',
#   '2018-08-27',
#   '2018-08-24',
#   '2018-08-23',
#   '2018-08-22',
#   '2018-08-21',
#   '2018-08-20',
#   '2018-08-17',
#   '2018-08-16',
#   '2018-08-15',
#   '2018-08-14',
#   '2018-08-13',
#   '2018-08-10',
#   '2018-08-09',
#   '2018-08-08',
#   '2018-08-07',
#   '2018-08-06',
#   '2018-08-03',
#   '2018-08-02',
#   '2018-08-01',
#   '2018-07-31',
#   '2018-07-30',
#   '2018-07-27',
#   '2018-07-26',
#   '2018-07-25',
#   '2018-07-24',
#   '2018-07-23',
#   '2018-07-20',
#   '2018-07-19',
#   '2018-07-18',
#   '2018-07-17',
#   '2018-07-16',
#   '2018-07-13',
#   '2018-07-12',
#   '2018-07-11',
#   '2018-07-10',
#   '2018-07-09',
#   '2018-07-06',
#   '2018-07-05',
#   '2018-07-03',
#   '2018-07-02',
#   '2018-06-29',
#   '2018-06-28',
#   '2018-06-27',
#   '2018-06-26',
#   '2018-06-25',
#   '2018-06-22',
#   '2018-06-21',
#   '2018-06-20',
#   '2018-06-19',
#   '2018-06-18',
#   '2018-06-15',
#   '2018-06-14',
#   '2018-06-13',
#   '2018-06-12',
#   '2018-06-11',
#   '2018-06-08',
#   '2018-06-07',
#   '2018-06-06',
#   '2018-06-05',
#   '2018-06-04',
#   '2018-06-01',
#   '2018-05-31',
#   '2018-05-30',
#   '2018-05-29',
#   '2018-05-25',
#   '2018-05-24',
#   '2018-05-23',
#   '2018-05-22',
#   '2018-05-21',
#   '2018-05-18',
#   '2018-05-17',
#   '2018-05-16',
#   '2018-05-15',
#   '2018-05-14',
#   '2018-05-11',
#   '2018-05-10',
#   '2018-05-09',
#   '2018-05-08',
#   '2018-05-07',
#   '2018-05-04',
#   '2018-05-03',
#   '2018-05-02',
#   '2018-05-01',
#   '2018-04-30',
#   '2018-04-27',
#   '2018-04-26',
#   '2018-04-25',
#   '2018-04-24',
#   '2018-04-23',
#   '2018-04-20',
#   '2018-04-19',
#   '2018-04-18',
#   '2018-04-17',
#   '2018-04-16',
#   '2018-04-13',
#   '2018-04-12',
#   '2018-04-11',
#   '2018-04-10',
#   '2018-04-09',
#   '2018-04-06',
#   '2018-04-05',
#   '2018-04-04',
#   '2018-04-03',
#   '2018-04-02',
#   '2018-03-29',
#   '2018-03-28',
#   '2018-03-27',
#   '2018-03-26',
#   '2018-03-23',
#   '2018-03-22',
#   '2018-03-21',
#   '2018-03-20',
#   '2018-03-19',
#   '2018-03-16',
#   '2018-03-15',
#   '2018-03-14',
#   '2018-03-13',
#   '2018-03-12',
#   '2018-03-09',
#   '2018-03-08',
#   '2018-03-07',
#   '2018-03-06',
#   '2018-03-05',
#   '2018-03-02',
#   '2018-03-01',
#   '2018-02-28',
#   '2018-02-27',
#   '2018-02-26',
#   '2018-02-23',
#   '2018-02-22',
#   '2018-02-21',
#   '2018-02-20',
#   '2018-02-16',
#   '2018-02-15',
#   '2018-02-14',
#   '2018-02-13',
#   '2018-02-12',
#   '2018-02-09',
#   '2018-02-08',
#   '2018-02-07',
#   '2018-02-06',
#   '2018-02-05',
#   '2018-02-02',
#   '2018-02-01',
#   '2018-01-31',
#   '2018-01-30',
#   '2018-01-29',
#   '2018-01-26',
#   '2018-01-25',
#   '2018-01-24',
#   '2018-01-23',
#   '2018-01-22',
#   '2018-01-19',
#   '2018-01-18',
#   '2018-01-17',
#   '2018-01-16',
#   '2018-01-12',
#   '2018-01-11',
#   '2018-01-10',
#   '2018-01-09',
#   '2018-01-08',
#   '2018-01-05',
#   '2018-01-04',
#   '2018-01-03',
#   '2018-01-02',
#   '2017-12-29',
#   '2017-12-28',
#   '2017-12-27',
#   '2017-12-26',
#   '2017-12-22',
#   '2017-12-21',
#   '2017-12-20',
#   '2017-12-19',
#   '2017-12-18',
#   '2017-12-15',
#   '2017-12-14',
#   '2017-12-13',
#   '2017-12-12',
#   '2017-12-11',
#   '2017-12-08',
#   '2017-12-07',
#   '2017-12-06',
#   '2017-12-05',
#   '2017-12-04',
#   '2017-12-01',
#   '2017-11-30',
#   '2017-11-29',
#   '2017-11-28',
#   '2017-11-27',
#   '2017-11-24',
#   '2017-11-22',
#   '2017-11-21',
#   '2017-11-20',
#   '2017-11-17',
#   '2017-11-16',
#   '2017-11-15',
#   '2017-11-14',
#   '2017-11-13',
#   '2017-11-10',
#   '2017-11-09',
#   '2017-11-08',
#   '2017-11-07',
#   '2017-11-06',
#   '2017-11-03',
#   '2017-11-02',
#   '2017-11-01',
#   '2017-10-31',
#   '2017-10-30',
#   '2017-10-27',
#   '2017-10-26',
#   '2017-10-25',
#   '2017-10-24',
#   '2017-10-23',
#   '2017-10-20',
#   '2017-10-19',
#   '2017-10-18',
#   '2017-10-17',
#   '2017-10-16',
#   '2017-10-13',
#   '2017-10-12',
#   '2017-10-11',
#   '2017-10-10',
#   '2017-10-09',
#   '2017-10-06',
#   '2017-10-05',
#   '2017-10-04',
#   '2017-10-03',
#   '2017-10-02',
#   '2017-09-29',
#   '2017-09-28',
#   '2017-09-27',
#   '2017-09-26',
#   '2017-09-25',
#   '2017-09-22',
#   '2017-09-21',
#   '2017-09-20',
#   '2017-09-19',
#   '2017-09-18',
#   '2017-09-15',
#   '2017-09-14',
#   '2017-09-13',
#   '2017-09-12',
#   '2017-09-11',
#   '2017-09-08',
#   '2017-09-07',
#   '2017-09-06',
#   '2017-09-05',
#   '2017-09-01',
#   '2017-08-31',
#   '2017-08-30',
#   '2017-08-29',
#   '2017-08-28',
#   '2017-08-25',
#   '2017-08-24',
#   '2017-08-23',
#   '2017-08-22',
#   '2017-08-21',
#   '2017-08-18',
#   '2017-08-17',
#   '2017-08-16',
#   '2017-08-15',
#   '2017-08-14',
#   '2017-08-11',
#   '2017-08-10',
#   '2017-08-09',
#   '2017-08-08',
#   '2017-08-07',
#   '2017-08-04',
#   '2017-08-03',
#   '2017-08-02',
#   '2017-08-01',
#   '2017-07-31',
#   '2017-07-28',
#   '2017-07-27',
#   '2017-07-26',
#   '2017-07-25',
#   '2017-07-24',
#   '2017-07-21',
#   '2017-07-20',
#   '2017-07-19',
#   '2017-07-18',
#   '2017-07-17',
#   '2017-07-14',
#   '2017-07-13',
#   '2017-07-12',
#   '2017-07-11',
#   '2017-07-10',
#   '2017-07-07',
#   '2017-07-06',
#   '2017-07-05',
#   '2017-07-03',
#   '2017-06-30',
#   '2017-06-29',
#   '2017-06-28',
#   '2017-06-27',
#   '2017-06-26',
#   '2017-06-23',
#   '2017-06-22',
#   '2017-06-21',
#   '2017-06-20',
#   '2017-06-19',
#   '2017-06-16',
#   '2017-06-15',
#   '2017-06-14',
#   '2017-06-13',
#   '2017-06-12',
#   '2017-06-09',
#   '2017-06-08',
#   '2017-06-07',
#   '2017-06-06',
#   '2017-06-05',
#   '2017-06-02',
#   '2017-06-01',
#   '2017-05-31',
#   '2017-05-30',
#   '2017-05-26',
#   '2017-05-25',
#   '2017-05-24',
#   '2017-05-23',
#   '2017-05-22',
#   '2017-05-19',
#   '2017-05-18',
#   '2017-05-17',
#   '2017-05-16',
#   '2017-05-15',
#   '2017-05-12',
#   '2017-05-11',
#   '2017-05-10',
#   '2017-05-09',
#   '2017-05-08',
#   '2017-05-05',
#   '2017-05-04',
#   '2017-05-03',
#   '2017-05-02',
#   '2017-05-01',
#   '2017-04-28',
#   '2017-04-27',
#   '2017-04-26',
#   '2017-04-25',
#   '2017-04-24',
#   '2017-04-21',
#   '2017-04-20',
#   '2017-04-19',
#   '2017-04-18',
#   '2017-04-17',
#   '2017-04-13',
#   '2017-04-12',
#   '2017-04-11',
#   '2017-04-10',
#   '2017-04-07',
#   '2017-04-06',
#   '2017-04-05',
#   '2017-04-04',
#   '2017-04-03',
#   '2017-03-31',
#   '2017-03-30',
#   '2017-03-29',
#   '2017-03-28',
#   '2017-03-27',
#   '2017-03-24',
#   '2017-03-23',
#   '2017-03-22',
#   '2017-03-21',
#   '2017-03-20',
#   '2017-03-17',
#   '2017-03-16',
#   '2017-03-15',
#   '2017-03-14',
#   '2017-03-13',
#   '2017-03-10',
#   '2017-03-09',
#   '2017-03-08',
#   '2017-03-07',
#   '2017-03-06',
#   '2017-03-03',
#   '2017-03-02',
#   '2017-03-01',
#   '2017-02-28',
#   '2017-02-27',
#   '2017-02-24',
#   '2017-02-23',
#   '2017-02-22',
#   '2017-02-21',
#   '2017-02-17',
#   '2017-02-16',
#   '2017-02-15',
#   '2017-02-14',
#   '2017-02-13',
#   '2017-02-10',
#   '2017-02-09',
#   '2017-02-08',
#   '2017-02-07',
#   '2017-02-06',
#   '2017-02-03',
#   '2017-02-02',
#   '2017-02-01',
#   '2017-01-31',
#   '2017-01-30',
#   '2017-01-27',
#   '2017-01-26',
#   '2017-01-25',
#   '2017-01-24',
#   '2017-01-23',
#   '2017-01-20',
#   '2017-01-19',
#   '2017-01-18',
#   '2017-01-17',
#   '2017-01-13',
#   '2017-01-12',
#   '2017-01-11',
#   '2017-01-10',
#   '2017-01-09',
#   '2017-01-06',
#   '2017-01-05',
#   '2017-01-04',
#   '2017-01-03',
#   '2016-12-30',
#   '2016-12-29',
#   '2016-12-28',
#   '2016-12-27',
#   '2016-12-23',
#   '2016-12-22',
#   '2016-12-21',
#   '2016-12-20',
#   '2016-12-19',
#   '2016-12-16',
#   '2016-12-15',
#   '2016-12-14',
#   '2016-12-13',
#   '2016-12-12',
#   '2016-12-09',
#   '2016-12-08',
#   '2016-12-07',
#   '2016-12-06',
#   '2016-12-05',
#   '2016-12-02',
#   '2016-12-01',
#   '2016-11-30',
#   '2016-11-29',
#   '2016-11-28',
#   '2016-11-25',
#   '2016-11-23',
#   '2016-11-22',
#   '2016-11-21',
#   '2016-11-18',
#   '2016-11-17',
#   '2016-11-16',
#   '2016-11-15',
#   '2016-11-14',
#   '2016-11-11',
#   '2016-11-10',
#   '2016-11-09',
#   '2016-11-08',
#   '2016-11-07',
#   '2016-11-04',
#   '2016-11-03',
#   '2016-11-02',
#   '2016-11-01',
#   '2016-10-31',
#   '2016-10-28',
#   '2016-10-27',
#   '2016-10-26',
#   '2016-10-25',
#   '2016-10-24',
#   '2016-10-21',
#   '2016-10-20',
#   '2016-10-19',
#   '2016-10-18',
#   '2016-10-17',
#   '2016-10-14',
#   '2016-10-13',
#   '2016-10-12',
#   '2016-10-11',
#   '2016-10-10',
#   '2016-10-07',
#   '2016-10-06',
#   '2016-10-05',
#   '2016-10-04',
#   '2016-10-03',
#   '2016-09-30',
#   '2016-09-29',
#   '2016-09-28',
#   '2016-09-27',
#   '2016-09-26',
#   '2016-09-23',
#   '2016-09-22',
#   '2016-09-21',
#   '2016-09-20',
#   '2016-09-19',
#   '2016-09-16',
#   '2016-09-15',
#   '2016-09-14',
#   '2016-09-13',
#   '2016-09-12',
#   '2016-09-09',
#   '2016-09-08',
#   '2016-09-07',
#   '2016-09-06',
#   '2016-09-02',
#   '2016-09-01',
#   '2016-08-31',
#   '2016-08-30',
#   '2016-08-29',
#   '2016-08-26',
#   '2016-08-25',
#   '2016-08-24',
#   '2016-08-23',
#   '2016-08-22',
#   '2016-08-19',
#   '2016-08-18',
#   '2016-08-17',
#   '2016-08-16',
#   '2016-08-15',
#   '2016-08-12',
#   '2016-08-11',
#   '2016-08-10',
#   '2016-08-09',
#   '2016-08-08',
#   '2016-08-05',
#   '2016-08-04',
#   '2016-08-03',
#   '2016-08-02',
#   '2016-08-01',
#   '2016-07-29',
#   '2016-07-28',
#   '2016-07-27',
#   '2016-07-26',
#   '2016-07-25',
#   '2016-07-22',
#   '2016-07-21',
#   '2016-07-20',
#   '2016-07-19',
#   '2016-07-18',
#   '2016-07-15',
#   '2016-07-14',
#   '2016-07-13',
#   '2016-07-12',
#   '2016-07-11',
#   '2016-07-08',
#   '2016-07-07',
#   '2016-07-06',
#   '2016-07-05',
#   '2016-07-01',
#   '2016-06-30',
#   '2016-06-29',
#   '2016-06-28',
#   '2016-06-27',
#   '2016-06-24',
#   '2016-06-23',
#   '2016-06-22',
#   '2016-06-21',
#   '2016-06-20',
#   '2016-06-17',
#   '2016-06-16',
#   '2016-06-15',
#   '2016-06-14',
#   '2016-06-13',
#   '2016-06-10',
#   '2016-06-09',
#   '2016-06-08',
#   '2016-06-07',
#   '2016-06-06',
#   '2016-06-03',
#   '2016-06-02',
#   '2016-06-01',
#   '2016-05-31',
#   '2016-05-27',
#   '2016-05-26',
#   '2016-05-25',
#   '2016-05-24',
#   '2016-05-23',
#   '2016-05-20',
#   '2016-05-19',
#   '2016-05-18',
#   '2016-05-17',
#   '2016-05-16',
#   '2016-05-13',
#   '2016-05-12',
#   '2016-05-11',
#   '2016-05-10',
#   '2016-05-09',
#   '2016-05-06',
#   '2016-05-05',
#   '2016-05-04',
#   '2016-05-03',
#   '2016-05-02',
#   '2016-04-29',
#   '2016-04-28',
#   '2016-04-27',
#   '2016-04-26',
#   '2016-04-25',
#   '2016-04-22',
#   '2016-04-21',
#   '2016-04-20',
#   '2016-04-19',
#   '2016-04-18',
#   '2016-04-15',
#   '2016-04-14',
#   '2016-04-13',
#   '2016-04-12',
#   '2016-04-11',
#   '2016-04-08',
#   '2016-04-07',
#   '2016-04-06',
#   '2016-04-05',
#   '2016-04-04',
#   '2016-04-01',
#   '2016-03-31',
#   '2016-03-30',
#   '2016-03-29',
#   '2016-03-28',
#   '2016-03-24',
#   '2016-03-23',
#   '2016-03-22',
#   '2016-03-21',
#   '2016-03-18',
#   '2016-03-17',
#   '2016-03-16',
#   '2016-03-15',
#   '2016-03-14',
#   '2016-03-11',
#   '2016-03-10',
#   '2016-03-09',
#   '2016-03-08',
#   '2016-03-07',
#   '2016-03-04',
#   '2016-03-03',
#   '2016-03-02',
#   '2016-03-01',
#   '2016-02-29',
#   '2016-02-26',
#   '2016-02-25',
#   '2016-02-24',
#   '2016-02-23',
#   '2016-02-22',
#   '2016-02-19',
#   '2016-02-18',
#   '2016-02-17',
#   '2016-02-16',
#   '2016-02-12',
#   '2016-02-11',
#   '2016-02-10',
#   '2016-02-09',
#   '2016-02-08',
#   '2016-02-05',
#   '2016-02-04',
#   '2016-02-03',
#   '2016-02-02',
#   '2016-02-01',
#   '2016-01-29',
#   '2016-01-28',
#   '2016-01-27',
#   '2016-01-26',
#   '2016-01-25',
#   '2016-01-22',
#   '2016-01-21',
#   '2016-01-20',
#   '2016-01-19',
#   '2016-01-15',
#   '2016-01-14',
#   '2016-01-13',
#   '2016-01-12',
#   '2016-01-11',
#   '2016-01-08',
#   '2016-01-07',
#   '2016-01-06',
#   '2016-01-05',
#   '2016-01-04',
#   '2015-12-31',
#   '2015-12-30',
#   '2015-12-29',
#   '2015-12-28',
#   '2015-12-24',
#   '2015-12-23',
#   '2015-12-22',
#   '2015-12-21',
#   '2015-12-18',
#   '2015-12-17',
#   '2015-12-16',
#   '2015-12-15',
#   '2015-12-14',
#   '2015-12-11',
#   '2015-12-10',
#   '2015-12-09',
#   '2015-12-08',
#   '2015-12-07',
#   '2015-12-04',
#   '2015-12-03',
#   '2015-12-02',
#   '2015-12-01',
#   '2015-11-30',
#   '2015-11-27',
#   '2015-11-25',
#   '2015-11-24',
#   '2015-11-23',
#   '2015-11-20',
#   '2015-11-19',
#   '2015-11-18',
#   '2015-11-17',
#   '2015-11-16',
#   '2015-11-13',
#   '2015-11-12',
#   '2015-11-11',
#   '2015-11-10',
#   '2015-11-09',
#   '2015-11-06',
#   '2015-11-05',
#   '2015-11-04',
#   '2015-11-03',
#   '2015-11-02',
#   '2015-10-30',
#   '2015-10-29',
#   '2015-10-28',
#   '2015-10-27',
#   '2015-10-26',
#   '2015-10-23',
#   '2015-10-22',
#   '2015-10-21',
#   '2015-10-20',
#   '2015-10-19',
#   '2015-10-16',
#   '2015-10-15',
#   '2015-10-14',
#   '2015-10-13',
#   '2015-10-12',
#   '2015-10-09',
#   '2015-10-08',
#   '2015-10-07',
#   '2015-10-06',
#   '2015-10-05',
#   '2015-10-02',
#   '2015-10-01',
#   '2015-09-30',
#   '2015-09-29',
#   '2015-09-28',
#   '2015-09-25',
#   '2015-09-24',
#   '2015-09-23',
#   '2015-09-22',
#   '2015-09-21',
#   '2015-09-18',
#   '2015-09-17',
#   '2015-09-16',
#   '2015-09-15',
#   '2015-09-14',
#   '2015-09-11',
#   '2015-09-10',
#   '2015-09-09',
#   '2015-09-08',
#   '2015-09-04',
#   '2015-09-03',
#   '2015-09-02',
#   '2015-09-01',
#   '2015-08-31',
#   '2015-08-28',
#   '2015-08-27',
#   '2015-08-26',
#   '2015-08-25',
#   '2015-08-24',
#   '2015-08-21',
#   '2015-08-20',
#   '2015-08-19',
#   '2015-08-18',
#   '2015-08-17',
#   '2015-08-14',
#   '2015-08-13',
#   '2015-08-12',
#   '2015-08-11',
#   '2015-08-10',
#   '2015-08-07',
#   '2015-08-06',
#   '2015-08-05',
#   '2015-08-04',
#   '2015-08-03',
#   '2015-07-31',
#   '2015-07-30',
#   '2015-07-29',
#   '2015-07-28',
#   '2015-07-27',
#   '2015-07-24',
#   '2015-07-23',
#   '2015-07-22',
#   '2015-07-21',
#   '2015-07-20',
#   '2015-07-17',
#   '2015-07-16',
#   '2015-07-15',
#   '2015-07-14',
#   '2015-07-13',
#   '2015-07-10',
#   '2015-07-09',
#   '2015-07-08',
#   '2015-07-07',
#   '2015-07-06',
#   '2015-07-02',
#   '2015-07-01',
#   '2015-06-30',
#   '2015-06-29',
#   '2015-06-26',
#   '2015-06-25',
#   '2015-06-24',
#   '2015-06-23',
#   '2015-06-22',
#   '2015-06-19',
#   '2015-06-18',
#   '2015-06-17',
#   '2015-06-16',
#   '2015-06-15',
#   '2015-06-12',
#   '2015-06-11',
#   '2015-06-10',
#   '2015-06-09',
#   '2015-06-08',
#   '2015-06-05',
#   '2015-06-04',
#   '2015-06-03',
#   '2015-06-02',
#   '2015-06-01',
#   '2015-05-29',
#   '2015-05-28',
#   '2015-05-27',
#   '2015-05-26',
#   '2015-05-22',
#   '2015-05-21',
#   '2015-05-20',
#   '2015-05-19',
#   '2015-05-18',
#   ...],
#  'Volume': ['2861174',
#   '2313431',
#   '2394734',
#   '3696034',
#   '3054429',
#   '2183302',
#   '1712673',
#   '2557964',
#   '2404416',
#   '2552802',
#   '1404771',
#   '1578637',
#   '1392610',
#   '3401324',
#   '5802887',
#   '2094152',
#   '1768524',
#   '3029406',
#   '3456519',
#   '1918447',
#   '2807283',
#   '1697360',
#   '2334449',
#   '2860403',
#   '2640946',
#   '3186287',
#   '5531528',
#   '5061333',
#   '5049801',
#   '6422744',
#   '2982884',
#   '3280489',
#   '2154638',
#   '2992381',
#   '7251424',
#   '3528948',
#   '1533635',
#   '1525427',
#   '1720634',
#   '1737609',
#   '1972764',
#   '3593038',
#   '4522125',
#   '2881233',
#   '2168151',
#   '2590160',
#   '2538251',
#   '3645834',
#   '4280372',
#   '2608466',
#   '2361712',
#   '2230056',
#   '2514559',
#   '2202657',
#   '2530087',
#   '2428301',
#   '2474472',
#   '2570392',
#   '4602655',
#   '1903171',
#   '5001925',
#   '4054723',
#   '5542951',
#   '2551715',
#   '3743029',
#   '2254494',
#   '2706505',
#   '4056939',
#   '4308318',
#   '3991904',
#   '4542651',
#   '2070801',
#   '2751082',
#   '3697637',
#   '2373602',
#   '1832142',
#   '1987181',
#   '2322893',
#   '1279050',
#   '1500776',
#   '2388271',
#   '4223853',
#   '2997552',
#   '2791882',
#   '3196375',
#   '2501408',
#   '3149600',
#   '1894190',
#   '1879707',
#   '2937297',
#   '2372364',
#   '2174922',
#   '4374337',
#   '4521486',
#   '5236222',
#   '3534084',
#   '3151311',
#   '3038267',
#   '3038895',
#   '2711154',
#   '2923646',
#   '3905500',
#   '2450432',
#   '3785199',
#   '3466366',
#   '3266132',
#   '3802255',
#   '2592195',
#   '4852100',
#   '3035536',
#   '2004931',
#   '1926952',
#   '1078799',
#   '2205505',
#   '2030427',
#   '2287792',
#   '5688966',
#   '4223569',
#   '2187198',
#   '2331872',
#   '2856281',
#   '1865379',
#   '1694506',
#   '1723454',
#   '1946071',
#   '2326604',
#   '2587607',
#   '3232864',
#   '2822845',
#   '4223406',
#   '3774138',
#   '2582884',
#   '3465893',
#   '2484658',
#   '2054934',
#   '2101488',
#   '2767187',
#   '2943256',
#   '2205410',
#   '2768584',
#   '2658279',
#   '4585275',
#   '3665470',
#   '3889522',
#   '1920425',
#   '3675361',
#   '1954928',
#   '2185396',
#   '2061610',
#   '1739293',
#   '2353166',
#   '1763632',
#   '2289858',
#   '3001418',
#   '2471341',
#   '2754515',
#   '6404530',
#   '3317624',
#   '2478231',
#   '1777489',
#   '1461433',
#   '3187421',
#   '2609559',
#   '2082268',
#   '2242106',
#   '3224309',
#   '2625057',
#   '2562948',
#   '3222108',
#   '1501366',
#   '2074537',
#   '1552798',
#   '3616942',
#   '2067545',
#   '2036353',
#   '2061458',
#   '2713538',
#   '2433471',
#   '2059090',
#   '2067936',
#   '2363188',
#   '4388655',
#   '2571346',
#   '2337567',
#   '4540912',
#   '1724724',
#   '3059135',
#   '3017718',
#   '3486582',
#   '6532289',
#   '6363050',
#   '2389484',
#   '2822118',
#   '2921644',
#   '2186968',
#   '3633379',
#   '2697817',
#   '5503327',
#   '2040226',
#   '2730348',
#   '3211726',
#   '2194198',
#   '2114706',
#   '1793114',
#   '1499626',
#   '2413201',
#   '6101001',
#   '5835132',
#   '4294285',
#   '4816067',
#   '1847654',
#   '2389599',
#   '4498621',
#   '3327899',
#   '5145707',
#   '6252711',
#   '5309839',
#   '2767393',
#   '2409709',
#   '2221574',
#   '2452467',
#   '4656683',
#   '2698438',
#   '3674236',
#   '1959788',
#   '1677377',
#   '1472097',
#   '2422784',
#   '1929913',
#   '2969380',
#   '4521153',
#   '1889931',
#   '1157950',
#   '1590544',
#   '1629236',
#   '2375727',
#   '2025064',
#   '1229329',
#   '1468661',
#   '2611624',
#   '4042986',
#   '2269497',
#   '1965199',
#   '1521286',
#   '2722394',
#   '1449321',
#   '1983685',
#   '2502919',
#   '2198667',
#   '3765947',
#   '2571313',
#   '1757539',
#   '1997616',
#   '1911010',
#   '2115027',
#   '2493426',
#   '1855421',
#   '2835648',
#   '1910113',
#   '2535319',
#   '2321723',
#   '3019650',
#   '2489459',
#   '2665996',
#   '5314616',
#   '4476483',
#   '2414505',
#   '2687894',
#   '2604265',
#   '3228190',
#   '4517366',
#   '3645445',
#   '2545130',
#   '3076581',
#   '2624359',
#   '2950875',
#   '2179673',
#   '3074107',
#   '3365128',
#   '3806328',
#   '2292146',
#   '3124255',
#   '4288761',
#   '3824165',
#   '2106655',
#   '2816741',
#   '2006651',
#   '5063205',
#   '2944419',
#   '2551582',
#   '2079705',
#   '3275508',
#   '4681245',
#   '3759458',
#   '4165240',
#   '2914912',
#   '5407990',
#   '4861604',
#   '5777051',
#   '4201942',
#   '2900115',
#   '1287878',
#   '2319259',
#   '2268040',
#   '3964914',
#   '3362034',
#   '3404626',
#   '5440703',
#   '3190992',
#   '5615469',
#   '5096656',
#   '4991932',
#   '4165444',
#   '6956328',
#   '3873583',
#   '4950639',
#   '2255667',
#   '2124116',
#   '1914350',
#   '2507805',
#   '1413929',
#   '2522796',
#   '2116936',
#   '2684337',
#   '2278008',
#   '2510689',
#   '2059127',
#   '2348142',
#   '3844892',
#   '2364016',
#   '2577964',
#   '2497608',
#   '2735103',
#   '2781625',
#   '3632600',
#   '2377675',
#   '2849232',
#   '3908206',
#   '2964394',
#   '2387387',
#   '1887740',
#   '2299528',
#   '1619640',
#   '2561326',
#   '2754670',
#   '1740441',
#   '2297256',
#   '3388810',
#   '3277212',
#   '4166540',
#   '3417962',
#   '1932037',
#   '2329078',
#   '2682439',
#   '3001281',
#   '2886212',
#   '1895512',
#   '2623967',
#   '1809397',
#   '2171992',
#   '2108714',
#   '1317478',
#   '1084675',
#   '1934515',
#   '2579463',
#   '2454424',
#   '1933084',
#   '1895996',
#   '3204344',
#   '2870868',
#   '1957495',
#   '1695556',
#   '3413057',
#   '2300358',
#   '2144191',
#   '2318323',
#   '1358467',
#   '1899578',
#   '2660908',
#   '1845132',
#   '1738099',
#   '1788453',
#   '2291755',
#   '1895669',
#   '1713469',
#   '1115095',
#   '2163723',
#   '2201994',
#   '5009509',
#   '1937101',
#   '2596240',
#   '3803235',
#   '2230420',
#   '1808430',
#   '2010604',
#   '3612061',
#   '2709245',
#   '1864455',
#   '1373877',
#   '2229678',
#   '1804039',
#   '1546271',
#   '2406442',
#   '1970242',
#   '2929752',
#   '2299969',
#   '2006718',
#   '3621549',
#   '3282304',
#   '2079877',
#   '2019664',
#   '3392007',
#   '2715793',
#   '2265686',
#   '2701858',
#   '2116611',
#   '3285153',
#   '1986998',
#   '2098222',
#   '4863010',
#   '2535383',
#   '4176157',
#   '3006918',
#   '2793197',
#   '1704616',
#   '3351048',
#   '3737755',
#   '7937265',
#   '4196991',
#   '2226049',
#   '1906551',
#   '1995405',
#   '2830225',
#   '3159361',
#   '2486500',
#   '5583534',
#   '2259853',
#   '3812885',
#   '3563869',
#   '2989826',
#   '2268171',
#   '1874220',
#   '3787273',
#   '3056809',
#   '4547683',
#   '3720285',
#   '3077390',
#   '4256658',
#   '6872388',
#   '4568114',
#   '3276114',
#   '2950259',
#   '2167704',
#   '3872698',
#   '2513450',
#   '3529384',
#   '2438264',
#   '2660562',
#   '4563519',
#   '4726248',
#   '3722065',
#   '3800506',
#   '4896318',
#   '3051049',
#   '2719800',
#   '3158241',
#   '3386523',
#   '5701863',
#   '1795617',
#   '2726160',
#   '5617407',
#   '3200733',
#   '4195312',
#   '2431525',
#   '3250885',
#   '3258551',
#   '3817302',
#   '2172827',
#   '5171755',
#   '2837922',
#   '2591349',
#   '3218831',
#   '2052780',
#   '1587536',
#   '2329457',
#   '1873800',
#   '2881779',
#   '1237482',
#   '2046949',
#   '3156942',
#   '2883462',
#   '2934732',
#   '3363478',
#   '4370931',
#   '3995800',
#   '4816983',
#   '4109094',
#   '2532978',
#   '1582371',
#   '2243135',
#   '2094371',
#   '4299285',
#   '2181344',
#   '3220582',
#   '3830614',
#   '3225344',
#   '3097507',
#   '1774989',
#   '1574977',
#   '2789304',
#   '2249434',
#   '2695646',
#   '3008283',
#   '2973646',
#   '3470292',
#   '3514154',
#   '4297445',
#   '2345578',
#   '2975019',
#   '5776593',
#   '4012550',
#   '2822894',
#   '3305643',
#   '5023171',
#   '3463149',
#   '2565501',
#   '2671650',
#   '2423596',
#   '2921079',
#   '3056531',
#   '3192821',
#   '5055912',
#   '6281487',
#   '2742584',
#   '3774001',
#   '6132384',
#   '2175672',
#   '3210852',
#   '6785503',
#   '7646503',
#   '3521101',
#   '3743290',
#   '4954952',
#   '5291655',
#   '8132677',
#   '3483539',
#   '3035229',
#   '2590387',
#   '4255803',
#   '4902426',
#   '2896542',
#   '4609245',
#   '6574586',
#   '10057362',
#   '2902814',
#   '3233331',
#   '2245886',
#   '2409486',
#   '2168619',
#   '3547919',
#   '10257250',
#   '5837059',
#   '4377759',
#   '3627704',
#   '5102694',
#   '7227539',
#   '5409614',
#   '3291193',
#   '3194135',
#   '2654943',
#   '2872640',
#   '2939027',
#   '3439877',
#   '5233273',
#   '5937290',
#   '2830749',
#   '2422714',
#   '1832676',
#   '4121179',
#   '3514190',
#   '3090039',
#   '5007815',
#   '4782630',
#   '5717786',
#   '4089799',
#   '3582566',
#   '3898077',
#   '3119661',
#   '2426042',
#   '2868697',
#   '1766836',
#   '1923936',
#   '868238',
#   '1000085',
#   '1961761',
#   '1944690',
#   '2467986',
#   '2808085',
#   '3672849',
#   '4518346',
#   '2975827',
#   '3303793',
#   '3032130',
#   '3853470',
#   '9437096',
#   '5568563',
#   '2634519',
#   '2676746',
#   '2444104',
#   '2885146',
#   '3387381',
#   '4229619',
#   '5484111',
#   '2818069',
#   '6795536',
#   '4598141',
#   '3166127',
#   '3356705',
#   '2997372',
#   '3938599',
#   '4841756',
#   '5194694',
#   '4362317',
#   '10019742',
#   '8236510',
#   '3861166',
#   '2985098',
#   '3161222',
#   '2420198',
#   '4922449',
#   '4180577',
#   '2089837',
#   '3112664',
#   '2672173',
#   '2911885',
#   '4359260',
#   '2908850',
#   '3523873',
#   '3467606',
#   '4149615',
#   '2744544',
#   '2891580',
#   '2556360',
#   '4797247',
#   '5021172',
#   '3884867',
#   '3039779',
#   '6391279',
#   '1929124',
#   '2184139',
#   '3784504',
#   '2108328',
#   '3756821',
#   '5106110',
#   '7921118',
#   '2094882',
#   '2134276',
#   '3075160',
#   '4703632',
#   '3383702',
#   '590251',
#   '897349',
#   '3812167',
#   '4241238',
#   '4111557',
#   '4193853',
#   '4518988',
#   '2759119',
#   '2807270',
#   '3176403',
#   '2574048',
#   '5074758',
#   '2429601',
#   '3806141',
#   '3397930',
#   '2873593',
#   '6799484',
#   '2664652',
#   '2755943',
#   '3531065',
#   '3619020',
#   '2820906',
#   '2485968',
#   '2840775',
#   '3964314',
#   '2898713',
#   '4426416',
#   '3976297',
#   '3264108',
#   '2544265',
#   '3637845',
#   '3283943',
#   '5481110',
#   '3624812',
#   '3317717',
#   '4135799',
#   '3311933',
#   '4868634',
#   '4082652',
#   '3950654',
#   '1990462',
#   '1828316',
#   '3147542',
#   '3396909',
#   '5094113',
#   '2740859',
#   '3761976',
#   '4358023',
#   '5376567',
#   '5857865',
#   '3876544',
#   '5432693',
#   '4288740',
#   '3382046',
#   '4249345',
#   '4142644',
#   '7483800',
#   '4769133',
#   '6529589',
#   '5710233',
#   '9108687',
#   '5117077',
#   '4979666',
#   '3386060',
#   '4322712',
#   '4380803',
#   '4132673',
#   '4985124',
#   '4605576',
#   '4970857',
#   '5404508',
#   '5089483',
#   '4862933',
#   '5424998',
#   '6374400',
#   '5145563',
#   '4583900',
#   '8144129',
#   '4038576',
#   '3585153',
#   '3914816',
#   '3883630',
#   '3912798',
#   '3926642',
#   '4841162',
#   '5533688',
#   '4877707',
#   '3823158',
#   '3607588',
#   '3758002',
#   '4105681',
#   '4475954',
#   '5310730',
#   '6281787',
#   '4238093',
#   '5039133',
#   '5358630',
#   '5774600',
#   '3757922',
#   '3976626',
#   '4978620',
#   '5422065',
#   '4030134',
#   '4323137',
#   '4502903',
#   '7453084',
#   '11197072',
#   '5199542',
#   '4304936',
#   '3703347',
#   '6015950',
#   '8338076',
#   '4121407',
#   '3224423',
#   '4019584',
#   '3217929',
#   '3390788',
#   '4722575',
#   '3146330',
#   '3577564',
#   '2830921',
#   '5113947',
#   '5164668',
#   '2548865',
#   '5266931',
#   '5059656',
#   '4992788',
#   '4917282',
#   '6057205',
#   '9134647',
#   '6664007',
#   '5114512',
#   '5166765',
#   '4693929',
#   '6484061',
#   '3176786',
#   '7580607',
#   '14249313',
#   '11020046',
#   '6133537',
#   '5464863',
#   '5164786',
#   '4092888',
#   '4312006',
#   '4727542',
#   '7945421',
#   '7086374',
#   '6848809',
#   '5103131',
#   '4758805',
#   '5674284',
#   '5003475',
#   '6439450',
#   '7738699',
#   '5037438',
#   '6523484',
#   '6066380',
#   '4727461',
#   '10781780',
#   '6284852',
#   '3998549',
#   '2804770',
#   '3615685',
#   '4476965',
#   '4756953',
#   '5725180',
#   '6438618',
#   '7718028',
#   '6741658',
#   '6152550',
#   '4864075',
#   '5599379',
#   '8703802',
#   '4975565',
#   '7465453',
#   '8658447',
#   '6100393',
#   '5113046',
#   '6231156',
#   '2958253',
#   '4876078',
#   '1473075',
#   '2324883',
#   '2153055',
#   '2684539',
#   '818810',
#   '4817428',
#   '4163523',
#   '4834124',
#   '6799489',
#   '4352487',
#   '3390457',
#   '3722930',
#   '4946105',
#   '4758030',
#   '3517133',
#   '5725032',
#   '7861054',
#   '3936764',
#   '3399336',
#   '3865981',
#   '2583985',
#   '2647857',
#   '3522882',
#   '2406774',
#   '2491264',
#   '2228680',
#   '2780004',
#   '2016326',
#   '1832933',
#   '2676760',
#   '2846373',
#   '2148711',
#   '2536781',
#   '2641224',
#   '2002773',
#   '3839014',
#   '2345527',
#   '2642880',
#   '3134855',
#   '2953110',
#   '4062953',
#   '2823266',
#   '3174401',
#   '3851044',
#   '3535761',
#   '2697841',
#   '2018578',
#   '1978161',
#   '2052442',
#   '1831841',
#   '2786599',
#   '2488631',
#   '2867957',
#   '2699332',
#   '5407250',
#   '2474569',
#   '2533364',
#   '5070333',
#   '5707099',
#   '7589872',
#   '2584474',
#   '4294038',
#   '5048754',
#   '2907757',
#   '4725319',
#   '3409192',
#   '3199395',
#   '2685441',
#   '5438784',
#   '3781851',
#   '4488545',
#   '2835992',
#   '5187254',
#   '4249557',
#   '4327852',
#   '5933705',
#   '3140987',
#   '5021392',
#   '3349151',
#   '3156886',
#   '3341157',
#   '3201498',
#   '3029701',
#   '3172410',
#   '3433844',
#   '1769251',
#   '2924407',
#   '4499310',
#   '2852451',
#   '3737127',
#   '5314861',
#   '2516670',
#   '2153475',
#   '3512830',
#   '1851181',
#   '1839396',
#   '1375777',
#   '1608500',
#   '3141045',
#   '3291583',
#   '3416707',
#   '2638054',
#   '2963938',
#   '4045772',
#   '2127614',
#   '2385337',
#   '2036517',
#   '2057534',
#   '2595630',
#   '3475264',
#   '3139824',
#   '4963942',
#   '2546165',
#   '2784618',
#   '4651052',
#   '2209016',
#   '1721465',
#   '2228034',
#   '3610196',
#   '3119667',
#   '6235243',
#   '3449450',
#   '2650535',
#   '4235490',
#   '4327583',
#   '2696104',
#   '2034444',
#   '2832841',
#   '4930643',
#   '1415913',
#   '1018207',
#   '1343109',
#   '1506682',
#   '1834078',
#   '1189044',
#   '1555770',
#   '1564009',
#   '1652548',
#   '1625000',
#   '1349468',
#   '1435089',
#   '1839274',
#   '3348774',
#   '2748818',
#   '1602593',
#   '1371055',
#   '1341277',
#   '2674798',
#   '2498845',
#   '1833496',
#   '1471058',
#   '1795888',
#   '2088153',
#   '1733066',
#   '2335475',
#   '1652819',
#   '1826247',
#   '3195947',
#   '1605689',
#   ...],
#  'Close': ['58.2900',
#   '58.0800',
#   '58.9200',
#   '57.4400',
#   '57.9400',
#   '58.9000',
#   '59.2900',
#   '59.3000',
#   '59.3400',
#   '59.4300',
#   '60.6000',
#   '60.8700',
#   '60.7700',
#   '60.4600',
#   '60.3400',
#   '62.4600',
#   '62.7800',
#   '62.0600',
#   '62.4000',
#   '61.8900',
#   '62.3600',
#   '61.0700',
#   '61.0400',
#   '61.0200',
#   '60.9800',
#   '59.8500',
#   '58.8500',
#   '58.0200',
#   '57.6600',
#   '57.7900',
#   '56.9500',
#   '56.1400',
#   '56.8300',
#   '56.6500',
#   '56.5200',
#   '56.9900',
#   '55.9800',
#   '56.0000',
#   '56.0300',
#   '55.3200',
#   '55.2800',
#   '54.6600',
#   '54.7400',
#   '59.1900',
#   '58.9200',
#   '58.6600',
#   '58.3600',
#   '58.2000',
#   '58.5200',
#   '58.8000',
#   '58.7000',
#   '58.8300',
#   '58.0200',
#   '58.4300',
#   '57.8300',
#   '57.1500',
#   '56.2800',
#   '56.3200',
#   '55.9200',
#   '55.7800',
#   '56.0300',
#   '56.2700',
#   '56.6400',
#   '56.2300',
#   '56.7400',
#   '55.9700',
#   '56.2700',
#   '55.1600',
#   '54.4100',
#   '52.6900',
#   '52.2600',
#   '49.8700',
#   '49.9200',
#   '50.3100',
#   '51.6400',
#   '51.6600',
#   '50.8900',
#   '50.6900',
#   '50.5500',
#   '50.5100',
#   '50.5900',
#   '50.8400',
#   '50.3000',
#   '49.6900',
#   '49.2500',
#   '46.6500',
#   '47.3500',
#   '48.4800',
#   '48.2100',
#   '48.3100',
#   '49.1000',
#   '47.3700',
#   '47.7600',
#   '47.7400',
#   '47.2700',
#   '47.7700',
#   '47.1600',
#   '46.6800',
#   '47.7000',
#   '47.0000',
#   '46.2900',
#   '45.3100',
#   '45.9700',
#   '46.3800',
#   '47.3800',
#   '47.8200',
#   '46.7600',
#   '47.0300',
#   '47.7600',
#   '46.3200',
#   '47.0800',
#   '47.5100',
#   '49.7100',
#   '49.0600',
#   '50.6500',
#   '50.9300',
#   '50.0500',
#   '48.9800',
#   '50.1800',
#   '50.2300',
#   '50.5700',
#   '52.1000',
#   '52.2100',
#   '51.5900',
#   '51.3700',
#   '50.8200',
#   '50.7700',
#   '49.2900',
#   '48.1100',
#   '47.6500',
#   '47.8200',
#   '47.3100',
#   '46.3100',
#   '48.2400',
#   '49.1000',
#   '48.6100',
#   '48.9600',
#   '50.1400',
#   '49.8500',
#   '49.5300',
#   '49.1900',
#   '48.9300',
#   '48.7300',
#   '50.1900',
#   '49.8300',
#   '49.8000',
#   '51.1600',
#   '51.3000',
#   '51.1900',
#   '50.9600',
#   '51.0200',
#   '51.3300',
#   '51.5300',
#   '52.2100',
#   '51.4800',
#   '51.5800',
#   '51.1500',
#   '49.2800',
#   '48.3400',
#   '47.5400',
#   '47.4500',
#   '47.2300',
#   '47.0900',
#   '46.2800',
#   '46.4400',
#   '46.2700',
#   '46.5900',
#   '46.7700',
#   '46.5900',
#   '48.0300',
#   '48.2500',
#   '48.9900',
#   '48.7600',
#   '48.7500',
#   '48.2900',
#   '47.2700',
#   '48.2800',
#   '47.8200',
#   '48.2000',
#   '48.2600',
#   '47.5600',
#   '47.4300',
#   '49.0300',
#   '49.4800',
#   '49.5300',
#   '50.3400',
#   '51.9700',
#   '51.5100',
#   '51.3400',
#   '52.7000',
#   '51.8500',
#   '53.7900',
#   '55.5000',
#   '54.8400',
#   '55.0600',
#   '55.0900',
#   '56.3100',
#   '55.8800',
#   '53.8000',
#   '53.8400',
#   '53.6300',
#   '54.9400',
#   '54.2400',
#   '53.6400',
#   '54.0000',
#   '54.0500',
#   '53.3800',
#   '56.2100',
#   '55.9700',
#   '54.6500',
#   '54.0800',
#   '53.8000',
#   '53.9600',
#   '55.4800',
#   '55.5200',
#   '54.9400',
#   '55.1100',
#   '54.1200',
#   '55.4600',
#   '54.7200',
#   '55.0700',
#   '54.9500',
#   '57.0600',
#   '56.7900',
#   '58.5000',
#   '58.7300',
#   '58.7700',
#   '59.1000',
#   '59.2200',
#   '59.6400',
#   '60.6700',
#   '58.5300',
#   '57.6600',
#   '57.5400',
#   '56.7000',
#   '56.7100',
#   '55.8200',
#   '56.9800',
#   '57.6000',
#   '57.7600',
#   '58.9600',
#   '59.1600',
#   '58.4100',
#   '58.9800',
#   '58.9300',
#   '57.5200',
#   '57.8500',
#   '57.3900',
#   '57.3500',
#   '56.5600',
#   '55.4100',
#   '55.4800',
#   '55.6200',
#   '55.4600',
#   '55.0200',
#   '54.5600',
#   '54.9500',
#   '55.1400',
#   '55.6800',
#   '55.2300',
#   '55.6800',
#   '55.5200',
#   '56.6000',
#   '56.5600',
#   '56.8500',
#   '54.7400',
#   '54.2300',
#   '54.2600',
#   '53.8100',
#   '53.1400',
#   '53.1400',
#   '50.9300',
#   '50.5500',
#   '51.5200',
#   '50.9800',
#   '51.2900',
#   '51.3100',
#   '51.5300',
#   '50.2000',
#   '50.6900',
#   '51.4500',
#   '50.5100',
#   '50.7900',
#   '53.2600',
#   '51.7000',
#   '51.6200',
#   '52.5800',
#   '52.6000',
#   '52.2000',
#   '52.0400',
#   '52.2200',
#   '52.0700',
#   '51.9100',
#   '52.6100',
#   '53.2200',
#   '52.2500',
#   '51.4800',
#   '52.6400',
#   '54.7100',
#   '56.5500',
#   '58.0100',
#   '57.0700',
#   '56.6100',
#   '55.9700',
#   '56.2700',
#   '57.8200',
#   '58.9000',
#   '58.0400',
#   '55.7100',
#   '55.1900',
#   '53.7200',
#   '52.2700',
#   '53.9000',
#   '55.1900',
#   '53.2900',
#   '54.3300',
#   '56.5200',
#   '56.1100',
#   '56.1700',
#   '56.6500',
#   '56.3100',
#   '55.7600',
#   '56.1500',
#   '55.6600',
#   '56.4500',
#   '56.0500',
#   '56.2400',
#   '56.2700',
#   '55.7800',
#   '57.6700',
#   '57.2400',
#   '56.0800',
#   '55.7400',
#   '55.6500',
#   '54.5400',
#   '54.7000',
#   '54.9500',
#   '54.7500',
#   '52.9300',
#   '52.7600',
#   '51.7500',
#   '51.4200',
#   '51.0900',
#   '51.4100',
#   '50.5700',
#   '49.4900',
#   '49.8800',
#   '49.1200',
#   '48.0600',
#   '48.6000',
#   '47.7000',
#   '47.9500',
#   '47.1700',
#   '47.0600',
#   '47.4500',
#   '47.2000',
#   '48.2900',
#   '48.3000',
#   '47.9000',
#   '47.8900',
#   '48.7100',
#   '48.8800',
#   '49.4300',
#   '49.0100',
#   '48.0500',
#   '47.8200',
#   '47.5900',
#   '47.6300',
#   '47.5600',
#   '48.0000',
#   '49.2000',
#   '49.5100',
#   '49.1200',
#   '50.5000',
#   '49.8900',
#   '50.3900',
#   '49.2400',
#   '49.4800',
#   '49.0300',
#   '47.9300',
#   '47.3300',
#   '47.4500',
#   '47.2100',
#   '47.1000',
#   '47.9800',
#   '47.9600',
#   '48.3700',
#   '48.1300',
#   '48.0200',
#   '49.7900',
#   '50.0200',
#   '50.0100',
#   '48.0800',
#   '47.7500',
#   '48.2600',
#   '48.0700',
#   '49.0800',
#   '48.7300',
#   '48.5200',
#   '48.3900',
#   '47.9300',
#   '47.1900',
#   '46.9500',
#   '46.9500',
#   '46.6100',
#   '47.0800',
#   '47.8200',
#   '47.8500',
#   '47.8200',
#   '48.4500',
#   '48.2400',
#   '47.6300',
#   '47.9600',
#   '48.8400',
#   '49.6600',
#   '49.2400',
#   '48.2700',
#   '49.5300',
#   '49.1500',
#   '48.8400',
#   '49.5300',
#   '49.0800',
#   '47.9100',
#   '48.1100',
#   '48.0300',
#   '47.6900',
#   '47.5900',
#   '47.3100',
#   '46.1500',
#   '45.2000',
#   '44.6400',
#   '44.3200',
#   '45.2400',
#   '44.2100',
#   '44.7600',
#   '44.6100',
#   '45.3700',
#   '46.1600',
#   '47.2900',
#   '47.8500',
#   '46.8300',
#   '46.1800',
#   '46.0100',
#   '47.1300',
#   '47.3800',
#   '46.6100',
#   '45.8700',
#   '46.0200',
#   '45.9300',
#   '43.9000',
#   '44.1400',
#   '44.5400',
#   '45.3600',
#   '45.4800',
#   '45.4500',
#   '45.1700',
#   '44.5600',
#   '44.6900',
#   '44.7200',
#   '44.2200',
#   '43.5000',
#   '43.1400',
#   '43.2900',
#   '43.6000',
#   '42.3100',
#   '41.8400',
#   '41.1700',
#   '40.1900',
#   '39.2800',
#   '39.1700',
#   '38.7100',
#   '38.3200',
#   '38.0000',
#   '39.2500',
#   '39.3000',
#   '39.3500',
#   '39.8900',
#   '41.1600',
#   '41.0400',
#   '41.7300',
#   '42.1100',
#   '41.2400',
#   '40.9600',
#   '40.4100',
#   '40.8000',
#   '40.6500',
#   '40.3100',
#   '41.3000',
#   '40.9800',
#   '41.3900',
#   '41.5000',
#   '41.8600',
#   '42.1300',
#   '41.3800',
#   '40.4100',
#   '40.1000',
#   '40.4500',
#   '39.1900',
#   '38.6900',
#   '38.7700',
#   '38.8100',
#   '38.4800',
#   '38.4700',
#   '38.9000',
#   '38.0700',
#   '38.3700',
#   '39.8400',
#   '40.0700',
#   '39.8200',
#   '39.5300',
#   '40.0800',
#   '40.3400',
#   '40.1100',
#   '39.5300',
#   '39.5700',
#   '38.5200',
#   '38.6200',
#   '39.0100',
#   '38.9400',
#   '39.2800',
#   '41.4400',
#   '40.8700',
#   '40.6100',
#   '40.9800',
#   '40.7500',
#   '41.0300',
#   '40.4700',
#   '40.6800',
#   '41.0800',
#   '40.8800',
#   '40.8600',
#   '40.2300',
#   '40.8400',
#   '41.3300',
#   '41.5600',
#   '41.0100',
#   '43.2600',
#   '43.0300',
#   '42.9300',
#   '43.0600',
#   '40.5500',
#   '40.8500',
#   '39.3900',
#   '39.4100',
#   '39.9000',
#   '40.6200',
#   '40.6800',
#   '41.7900',
#   '41.2300',
#   '42.9100',
#   '41.5200',
#   '41.8300',
#   '41.6900',
#   '42.5100',
#   '44.3400',
#   '46.1500',
#   '45.5000',
#   '46.1300',
#   '45.9300',
#   '46.2500',
#   '46.6500',
#   '45.4100',
#   '43.1400',
#   '42.9400',
#   '43.0200',
#   '42.7800',
#   '42.6700',
#   '44.6100',
#   '45.4400',
#   '44.7900',
#   '44.3900',
#   '45.3500',
#   '44.8600',
#   '45.9600',
#   '45.7000',
#   '43.8100',
#   '42.9300',
#   '43.0100',
#   '43.3300',
#   '42.4600',
#   '42.0400',
#   '42.1300',
#   '41.7000',
#   '41.0000',
#   '38.3600',
#   '38.3900',
#   '39.3200',
#   '39.2100',
#   '38.9600',
#   '38.4600',
#   '38.9000',
#   '38.8700',
#   '38.3500',
#   '38.1200',
#   '38.1800',
#   '38.8800',
#   '39.0800',
#   '38.1800',
#   '38.7600',
#   '39.2500',
#   '40.0400',
#   '40.8300',
#   '41.5000',
#   '41.1500',
#   '42.1200',
#   '41.5300',
#   '39.2500',
#   '39.4900',
#   '39.0200',
#   '38.3500',
#   '37.9100',
#   '38.3400',
#   '39.4500',
#   '39.3500',
#   '39.3900',
#   '39.0000',
#   '37.5100',
#   '36.5500',
#   '37.5600',
#   '37.3600',
#   '38.1300',
#   '39.6500',
#   '39.0800',
#   '39.2900',
#   '38.2400',
#   '35.7200',
#   '35.2800',
#   '33.9300',
#   '34.5600',
#   '34.4500',
#   '34.6800',
#   '34.8500',
#   '34.5300',
#   '34.2400',
#   '34.2100',
#   '34.1200',
#   '33.1200',
#   '32.8700',
#   '32.4200',
#   '32.6200',
#   '32.5500',
#   '31.8100',
#   '31.7700',
#   '31.8100',
#   '32.8100',
#   '32.5800',
#   '33.7100',
#   '33.1600',
#   '33.1800',
#   '33.7200',
#   '33.1000',
#   '33.5600',
#   '33.4000',
#   '33.7000',
#   '33.7400',
#   '32.2300',
#   '32.1700',
#   '32.4100',
#   '32.5200',
#   '32.0400',
#   '30.9100',
#   '30.8000',
#   '29.9000',
#   '30.4900',
#   '30.3200',
#   '29.8000',
#   '31.1200',
#   '30.7400',
#   '31.4700',
#   '31.0400',
#   '31.5800',
#   '31.1300',
#   '30.7800',
#   '30.1700',
#   '30.6000',
#   '31.6900',
#   '31.5400',
#   '31.8200',
#   '31.5000',
#   '32.1300',
#   '31.6100',
#   '32.0600',
#   '32.6300',
#   '32.2200',
#   '32.4000',
#   '31.7300',
#   '31.0800',
#   '32.4600',
#   '32.0700',
#   '32.8700',
#   '33.2700',
#   '32.7400',
#   '32.4600',
#   '33.0200',
#   '32.7900',
#   '32.6800',
#   '32.8200',
#   '32.8400',
#   '32.8200',
#   '32.3900',
#   '31.0700',
#   '31.3500',
#   '31.5700',
#   '30.8000',
#   '31.1900',
#   '32.9900',
#   '32.8600',
#   '33.4700',
#   '33.1400',
#   '33.1900',
#   '32.1300',
#   '31.5900',
#   '30.2800',
#   '30.8900',
#   '30.5000',
#   '31.5700',
#   '31.3000',
#   '29.9500',
#   '28.9600',
#   '28.0100',
#   '28.7600',
#   '31.0900',
#   '30.3400',
#   '30.1700',
#   '30.0500',
#   '29.1900',
#   '28.4500',
#   '28.3100',
#   '27.3200',
#   '28.0700',
#   '27.9400',
#   '28.7500',
#   '29.9300',
#   '29.3900',
#   '29.8300',
#   '28.3400',
#   '27.5800',
#   '27.5200',
#   '28.0400',
#   '28.7300',
#   '28.9200',
#   '29.5000',
#   '28.6400',
#   '28.3400',
#   '28.3100',
#   '28.7900',
#   '28.4600',
#   '29.4400',
#   '29.0200',
#   '28.2900',
#   '28.7000',
#   '29.4000',
#   '29.5900',
#   '28.4700',
#   '30.9000',
#   '30.5000',
#   '30.5500',
#   '31.4200',
#   '33.5000',
#   '33.6600',
#   '33.3800',
#   '32.8800',
#   '32.7100',
#   '32.3900',
#   '33.5600',
#   '34.0500',
#   '35.4200',
#   '33.8000',
#   '32.4600',
#   '31.6700',
#   '31.9000',
#   '31.8800',
#   '29.9400',
#   '28.9000',
#   '27.9900',
#   '26.9300',
#   '27.5700',
#   '27.3200',
#   '27.7900',
#   '28.1700',
#   '28.2700',
#   '28.5300',
#   '27.6000',
#   '27.7400',
#   '27.7100',
#   '27.6700',
#   '28.3500',
#   '28.9100',
#   '29.1300',
#   '29.4600',
#   '28.3900',
#   '27.2900',
#   '28.7400',
#   '29.1100',
#   '28.5900',
#   '29.0600',
#   '28.9800',
#   '31.9500',
#   '30.3200',
#   '28.8900',
#   '28.5600',
#   '26.9600',
#   '26.1000',
#   '25.5200',
#   '25.6600',
#   '25.9500',
#   '27.9900',
#   '29.1100',
#   '27.3700',
#   '27.1600',
#   '27.6300',
#   '26.8400',
#   '26.5200',
#   '24.5900',
#   '25.2500',
#   '25.3600',
#   '26.4300',
#   '26.2100',
#   '26.9600',
#   '25.0500',
#   '23.2500',
#   '24.5000',
#   '24.6500',
#   '24.4600',
#   '24.1000',
#   '24.3900',
#   '22.8300',
#   '23.7700',
#   '23.8700',
#   '22.7000',
#   '23.3200',
#   '23.6200',
#   '25.2000',
#   '23.8100',
#   '24.0200',
#   '24.7400',
#   '25.0700',
#   '25.8100',
#   '27.0300',
#   '28.6500',
#   '28.4100',
#   '29.1200',
#   '29.0900',
#   '29.2700',
#   '29.4000',
#   '29.7200',
#   '29.8600',
#   '28.2600',
#   '27.6400',
#   '27.3800',
#   '27.5200',
#   '28.9600',
#   '28.1800',
#   '28.1500',
#   '28.5300',
#   '29.9000',
#   '29.4100',
#   '28.5000',
#   '31.0100',
#   '31.7500',
#   '31.8000',
#   '32.4800',
#   '33.4000',
#   '33.0800',
#   '33.1100',
#   '33.6700',
#   '34.3300',
#   '34.2200',
#   '34.6800',
#   '34.9500',
#   '34.6300',
#   '33.4300',
#   '34.1900',
#   '34.2400',
#   '33.9900',
#   '34.9500',
#   '35.2600',
#   '34.7600',
#   '34.7200',
#   '34.9400',
#   '36.4000',
#   '36.4100',
#   '36.1500',
#   '36.5100',
#   '35.8600',
#   '36.7000',
#   '37.0100',
#   '37.8000',
#   '38.2900',
#   '37.9600',
#   '37.1800',
#   '37.5000',
#   '37.7600',
#   '38.3600',
#   '39.2100',
#   '39.2400',
#   '38.1700',
#   '38.9500',
#   '39.7400',
#   '38.8100',
#   '38.1900',
#   '35.4200',
#   '35.2700',
#   '34.7800',
#   '33.7600',
#   '33.8200',
#   '32.6500',
#   '32.0600',
#   '33.6000',
#   '34.0200',
#   '33.5400',
#   '34.0400',
#   '35.3200',
#   '35.5200',
#   '36.7600',
#   '37.2100',
#   '36.9000',
#   '37.4400',
#   '37.2100',
#   '36.3800',
#   '35.9900',
#   '35.9300',
#   '34.2300',
#   '35.5900',
#   '35.2000',
#   '34.3200',
#   '36.7200',
#   '36.6000',
#   '36.5600',
#   '34.7100',
#   '34.3000',
#   '34.1400',
#   '35.9900',
#   '36.7400',
#   '36.5700',
#   '37.7700',
#   '38.2400',
#   '38.5900',
#   '38.4400',
#   '39.2900',
#   '40.0700',
#   '41.6000',
#   '39.8000',
#   '40.2700',
#   '39.4700',
#   '38.5000',
#   '37.7700',
#   '38.6200',
#   '38.2000',
#   '38.4900',
#   '37.7800',
#   '36.9700',
#   '37.3900',
#   '38.5300',
#   '39.0300',
#   '39.9900',
#   '40.0100',
#   '40.3500',
#   '40.8100',
#   '40.4700',
#   '40.5100',
#   '40.6700',
#   '39.1400',
#   '38.5300',
#   '38.1700',
#   '39.7200',
#   '40.1400',
#   '41.0400',
#   '40.7300',
#   '41.2100',
#   '42.0400',
#   '42.8400',
#   '42.9000',
#   '43.5900',
#   '43.8000',
#   '43.5300',
#   '43.1600',
#   '43.6800',
#   '43.2700',
#   '43.0100',
#   '43.6100',
#   '44.0400',
#   '44.1700',
#   '43.9000',
#   '42.4200',
#   '43.2500',
#   '43.6300',
#   '43.8400',
#   '44.1000',
#   '44.6900',
#   '43.1700',
#   '43.7700',
#   '44.1400',
#   '44.4300',
#   '44.3000',
#   '44.8800',
#   '44.9700',
#   '44.6300',
#   '44.2500',
#   '45.6400',
#   ...]}

# %%
stock_dicts = {}
p = 0
for i in combined_stocks:
    stock_dict = {
        "Date" : dates,
        "Volume" : vols[p:p+1][0],
        "Close" : clos[p:p+1][0]
    }
  
    stock_dicts[combined_stocks[p]]=stock_dict
    p = p+1

# %%
pprint.pprint(combined_stocks)
len(combined_stocks)
#just all of the stocks for reference and selection purposes
# Out:
# ['PG',
#  'UL',
#  'UN',
#  'BHP',
#  'RIO',
#  'JPM',
#  'BAC',
#  'WFC',
#  'HSBC',
#  'C',
#  'XOM',
#  'CVX',
#  'BP',
#  'TOT',
#  'BBL',
#  'ABB',
#  'KMB',
#  'AME',
#  'BLL',
#  'CLX',
#  'KO',
#  'PEP',
#  'FMX',
#  'BUD',
#  'NKE',
#  'DAL',
#  'CSX',
#  'CHRW',
#  'UPS',
#  'UAL',
#  'CVS',
#  'UNH',
#  'AET',
#  'PFE',
#  'THC',
#  'S',
#  'T',
#  'VZ',
#  'CMCSA',
#  'TMUS',
#  'LEN',
#  'AMT',
#  'SPG',
#  'NLY',
#  'PLD',
#  'AAPL',
#  'FB',
#  'GOOGL',
#  'AMZN',
#  'MSFT']
# 50

# %%
for stock in combined_stocks:
    try:
        df = pd.DataFrame(data=stock_dicts[stock], index = dates)
        df.to_csv(f"../csvs/{stock}.csv")
    except PermissionError:
            print("Error")
# Out:
# Error

# %%
df = pd.DataFrame(data=stock_dicts["AMT"], index = dates)
df.to_csv(f"../csvs/_AMT.csv")
