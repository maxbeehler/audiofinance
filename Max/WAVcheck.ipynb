# %%
import pandas as pd

# %%
daily = pd.read_csv("daily_adjusted_GOOGL.csv")

# %%
daily

# %%
dailyfix = daily[['close','volume']]

# %%
dailyfix

dailyfix.to_csv("dailyfix.csv", index=False)

# %%
newdaily = pd.read_csv("dailyfix.csv")

# %%
newdaily

# %%
newdailylong = pd.read_csv("dailyfix.csv")
newdailylong

# %%
import numpy as np

# %%
import librosa

# %%
import matplotlib.pyplot as plt

# %%
from librosa import display

# %%
y, sr = librosa.load("rec.wav")

# %%
y

# %%
plt.figure(figsize=(14, 5))
librosa.display.waveplot(y, sr=sr)

# %%
x = librosa.core.resample(y, 2800, 16000)

# %%
librosa.display.waveplot(x, sr=sr)

# %%
librosa.output.write_wav('file_trim_5s.wav', x, sr)

# %%
y, sr = librosa.load("7061-6-0-0.wav")

# %%
plt.figure(figsize=(14, 5))
librosa.display.waveplot(y, sr=sr)

# %%
x, sr = librosa.load("9031-3-3-0.wav")

# %%
plt.figure(figsize=(14, 5))
librosa.display.waveplot(x, sr=sr)
